# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlinx7/Carlos-Eduardo/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input ("Python ou JavaScript?").lowe()
if nome == "python":
  print ("Vamos ver python então!")
print ("encerrando")
